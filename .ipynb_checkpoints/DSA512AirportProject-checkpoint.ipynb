# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

sns.set(style="darkgrid")

# %% [markdown]
# 1st Data source

# %%
data = pd.read_csv('largestToSmallest.csv')

# %%
data.head #or data.describe
# Out:
# <bound method NDFrame.head of     Rank                              Airports (large hubs)  IATA  \
# 0  -2017                                                NaN  Code
# 1      1   Hartsfield–Jackson Atlanta International Airport   ATL
# 2      2                  Los Angeles International Airport   LAX
# 3      3                       O'Hare International Airport   ORD
# 4      4            Dallas/Fort Worth International Airport   DFW
# 5      5                       Denver International Airport   DEN
# 6      6              John F. Kennedy International Airport   JFK
# 7      7                San Francisco International Airport   SFO
# 8      8                     McCarran International Airport   LAS
# 9      9               Seattle–Tacoma International Airport   SEA
# 10    10            Charlotte Douglas International Airport   CLT
# 11    11               Newark Liberty International Airport   EWR
# 12    12                      Orlando International Airport   MCO
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     Rank                              Airports (large hubs)  IATA  \
# 0  -2017                                                NaN  Code
# 1      1   Hartsfield–Jackson Atlanta International Airport   ATL
# 2      2                  Los Angeles International Airport   LAX
# 3      3                       O'Hare International Airport   ORD
# 4      4            Dallas/Fort Worth International Airport   DFW
# 5      5                       Denver International Airport   DEN
# 6      6              John F. Kennedy International Airport   JFK
# 7      7                San Francisco International Airport   SFO
# 8      8                     McCarran International Airport   LAS
# 9      9               Seattle–Tacoma International Airport   SEA
# 10    10            Charlotte Douglas International Airport   CLT
# 11    11               Newark Liberty International Airport   EWR
# 12    12                      Orlando International Airport   MCO
# ...

# %%
data.dtypes
# Out:
# Rank                      int64
# Airports (large hubs)    object
# IATA                     object
# Major city served        object
# State                    object
# 2017[3]                  object
# 2016[4]                  object
# 2015[5]                  object
# 2014[6]                  object
# 2013[7]                  object
# 2012[8]                  object
# 2011[9]                  object
# 2010[10]                 object
# 2009[11]                 object
# 2008[11]                 object
# 2007[12]                 object
# 2006[13]                 object
# 2005[14]                 object
# dtype: object

# %%
data.shape
# Out:
# (61, 18)

# %%
data
# Out:
#     Rank                              Airports (large hubs)  IATA  \
# 0  -2017                                                NaN  Code
# 1      1   Hartsfield–Jackson Atlanta International Airport   ATL
# 2      2                  Los Angeles International Airport   LAX
# 3      3                       O'Hare International Airport   ORD
# 4      4            Dallas/Fort Worth International Airport   DFW
# 5      5                       Denver International Airport   DEN
# 6      6              John F. Kennedy International Airport   JFK
# 7      7                San Francisco International Airport   SFO
# 8      8                     McCarran International Airport   LAS
# 9      9               Seattle–Tacoma International Airport   SEA
# 10    10            Charlotte Douglas International Airport   CLT
# 11    11               Newark Liberty International Airport   EWR
# 12    12                      Orlando International Airport   MCO
# ...

# %% [markdown]
# 2nd Data source

# %%
airportd= open('BuffaloAirport.txt','w')

# %% [markdown]
# 3rd Data Source

# %%
aviation= open('AviationSafety.txt','w')

# %% [markdown]
# 4th Data Source

# %%
data4 = pd.read_csv('aaa.csv')

# %%
data4
# Out:
#     Passengers (All Carriers - Buffalo, NY: Buffalo Niagara International (Origin Airport))  \
# 0                                                 Year
# 1                                                 2002
# 2                                                 2002
# 3                                                 2002
# 4                                                 2002
# 5                                                 2003
# 6                                                 2003
# 7                                                 2003
# 8                                                 2003
# 9                                                 2003
# 10                                                2003
# 11                                                2003
# 12                                                2003
# 13                                                2003
# 14                                                2003
# ...
