# %% [markdown]
# # Water Provision in East Africa

# %% [markdown]
# ## By: Andrea Khoury

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

sns.set(style="darkgrid")

# %%
df= pd.read_csv('Water_FullTrainingSet.csv.csv')
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0     3/14/2011         Roman        1390         Roman
# 1   8776         0.0      3/6/2013       Grumeti        1399       GRUMETI
# 2  34310        25.0     2/25/2013  Lottery Club         686  World vision
# 3  67743         0.0     1/28/2013        Unicef         263        UNICEF
# 4  19728         0.0     7/13/2011   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private       ...        \
# 0  34.938093  -9.856322                  none            0       ...
# 1  34.698766  -2.147466              Zahanati            0       ...
# 2  37.460664  -3.821329           Kwa Mahundi            0       ...
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0       ...
# 4  31.130847  -1.825359               Shuleni            0       ...
#
#   water_quality quality_group      quantity  quantity_group  \
# ...

# %%
df.shape
# Out:
# (59400, 41)

# %%
df.dtypes
# Out:
# id                         int64
# amount_tsh               float64
# date_recorded             object
# funder                    object
# gps_height                 int64
# installer                 object
# longitude                float64
# latitude                 float64
# wpt_name                  object
# num_private                int64
# basin                     object
# subvillage                object
# region                    object
# region_code                int64
# district_code              int64
# lga                       object
# ward                      object
# population                 int64
# public_meeting              bool
# recorded_by               object
# scheme_management         object
# scheme_name               object
# permit                      bool
# construction_year          int64
# extraction_type           object
# extraction_type_group     object
# extraction_type_class     object
# management                object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0     3/14/2011                     Roman        1390
# 1       8776         0.0      3/6/2013                   Grumeti        1399
# 2      34310        25.0     2/25/2013              Lottery Club         686
# 3      67743         0.0     1/28/2013                    Unicef         263
# 4      19728         0.0     7/13/2011               Action In A           0
# 5       9944        20.0     3/13/2011       Mkinga Distric Coun           0
# 6      19816         0.0     10/1/2012                      Dwsp           0
# 7      54551         0.0     10/9/2012                     Rwssp           0
# 8      53934         0.0     11/3/2012                  Wateraid           0
# 9      46144         0.0      8/3/2011               Isingiro Ho           0
# 10     49056         0.0     2/20/2011                   Private          62
# ...

# %%
df # Display
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0     3/14/2011                     Roman        1390
# 1       8776         0.0      3/6/2013                   Grumeti        1399
# 2      34310        25.0     2/25/2013              Lottery Club         686
# 3      67743         0.0     1/28/2013                    Unicef         263
# 4      19728         0.0     7/13/2011               Action In A           0
# 5       9944        20.0     3/13/2011       Mkinga Distric Coun           0
# 6      19816         0.0     10/1/2012                      Dwsp           0
# 7      54551         0.0     10/9/2012                     Rwssp           0
# 8      53934         0.0     11/3/2012                  Wateraid           0
# 9      46144         0.0      8/3/2011               Isingiro Ho           0
# 10     49056         0.0     2/20/2011                   Private          62
# ...

# %%
waterpoint_type =sns.countplot(y='waterpoint_type_group',data=df)

# %% [markdown]
# This data is describing the type of water source in Africa. Their main type comes from a communal standpipe, which is what it says, a standing pipe where water comes out from it. The hand pump is the next big source type for them and the graph also showed that they get zero water through dams and that makes sense because of the agriculture and warm temperatures on the continent of Africa.

# %%
waterp_hue = sns.countplot(y='waterpoint_type_group', data = df, hue ='quantity_group')

# %%
df['quantity_group']= df ['quantity_group'].replace('enough','sufficient')

# %%
#df['quantity_group']= df ['quantity_group'].replace('enough','sufficient') if you want to change other names

# %%
waterp_hue = sns.countplot(y='waterpoint_type_group', data = df, hue ='quantity_group')

# %% [markdown]
# How is the key different from the original graph key? The two graphs and keys look the same as each other but the only difference is what I told the computer to do. I changed the word "enough" from the first group to "sufficient" in the second group key.

# %% [markdown]
# 4

# %%
managepay = sns.countplot(y='management_group', data=df)

# %%
managepay = sns.countplot(y='payment_type', data=df)

# %%
managepay = sns.countplot(y='management_group', data=df, hue ='quantity_group')

# %% [markdown]
# Describe this graph: This data is describing the management type or how the water is being managed and adding the key or quality group to it as well. when you add hue this divides the bars on the graph into different status of the area or region.

# %%
managepay = sns.countplot(y='payment_type', data=df, hue ='quantity_group')

# %% [markdown]
# Describe this graph: This graph is showing the same thing as he one above but instead of management type it shows the payment type. It is dividing each payment type bar into each quality group and creating five different bars for each one.

# %% [markdown]
# ## Add on. Extra information you can make with this type of data

# %% [markdown]
# Finding the Latitude and Longitude of the talked about area.

# %%
plt.plot(df ['longitude'], df['latitude'],'g.', alpha=0.5)
